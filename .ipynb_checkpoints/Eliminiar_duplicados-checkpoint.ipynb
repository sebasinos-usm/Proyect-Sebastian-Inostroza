# %%
import os
import hashlib
import shutil

def calcular_hash(ruta_archivo):
    """Calcula el hash SHA-256 del contenido de un archivo."""
    sha256_hash = hashlib.sha256()
    try:
        with open(ruta_archivo, "rb") as f:
            for byte_block in iter(lambda: f.read(4096), b""):
                sha256_hash.update(byte_block)
        return sha256_hash.hexdigest()
    except IOError:
        print(f"No se pudo leer el archivo: {ruta_archivo}")
        return None

def limpiar_y_copiar_unicos(carpeta_entrada, carpeta_salida):
    """
    Identifica archivos únicos y los copia a una nueva carpeta manteniendo la estructura.
    Reporta los archivos que fueron identificados como duplicados.
    """
    hashes = {}
    duplicados_reporte = {}
    
    print(f"Escaneando archivos en: '{carpeta_entrada}'...")

    # 1. PRIMERA PASADA: Identificar todos los archivos únicos y duplicados
    for dirpath, _, filenames in os.walk(carpeta_entrada):
        for nombre_archivo in filenames:
            if nombre_archivo.lower().endswith(".txt"):
                ruta_completa = os.path.join(dirpath, nombre_archivo)
                file_hash = calcular_hash(ruta_completa)
                
                if file_hash:
                    if file_hash in hashes:
                        # Si el hash ya existe, es un duplicado. Lo guardamos para el reporte.
                        original = hashes[file_hash]
                        if original not in duplicados_reporte:
                            duplicados_reporte[original] = []
                        duplicados_reporte[original].append(ruta_completa)
                    else:
                        # Si es un hash nuevo, guardamos la ruta del archivo como el "original".
                        hashes[file_hash] = ruta_completa

    # 2. SEGUNDA PASADA: Copiar solo los archivos únicos a la nueva carpeta
    print(f"\nCopiando archivos únicos a: '{carpeta_salida}'...")
    if not os.path.exists(carpeta_salida):
        os.makedirs(carpeta_salida)

    for ruta_original in hashes.values():
        # Construir la ruta de destino replicando la estructura de carpetas
        ruta_destino = ruta_original.replace(carpeta_entrada, carpeta_salida, 1)
        
        # Crear el directorio de destino si no existe
        directorio_destino = os.path.dirname(ruta_destino)
        os.makedirs(directorio_destino, exist_ok=True)
        
        # Copiar el archivo
        shutil.copy2(ruta_original, ruta_destino)

    print(f"\nCopia de {len(hashes)} archivos únicos completada.")
    return duplicados_reporte

# --- USO ---

if __name__ == "__main__":
    # Carpeta que contiene los archivos originales (con posibles duplicados)
    CARPETA_A_REVISAR = 'Informes_en_Texto'
    
    # Nueva carpeta donde se guardarán solo los archivos únicos
    CARPETA_DESTINO_UNICOS = 'Informes_Unicos'
    
    archivos_duplicados = limpiar_y_copiar_unicos(CARPETA_A_REVISAR, CARPETA_DESTINO_UNICOS)
    
    if not archivos_duplicados:
        print("\n✅ ¡Excelente! No se encontraron archivos duplicados.")
    else:
        print(f"\n🚨 Se encontraron y omitieron los siguientes archivos duplicados:")
        for original, copias in archivos_duplicados.items():
            print("-" * 50)
            print(f"Archivo Original (copiado): {original}")
            for copia in copias:
                print(f"   -> Duplicado (omitido):   {copia}")
        print("-" * 50)
# Out:
# Escaneando archivos en: 'Informes_en_Texto'...
#
# Copiando archivos únicos a: 'Informes_Unicos'...
#
# Copia de 521 archivos únicos completada.
#
# 🚨 Se encontraron y omitieron los siguientes archivos duplicados:
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276009622794_134020288259811673.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276009622794_134020291966259107.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011454582_134027196895289706.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011454582_134027197041857563.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011474519_134027194828112068.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011474519_134027195079101110.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011523642_134027183869786251.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011523642_134027187491712776.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011761396_134027179552388774.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011761396_134027179750031515.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012324630_134015153736401968.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012324630_134015191776660880.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012324630_134020295228810449.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012345348_134020293472820615.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012345348_134020294059208966.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012346885_134020293568384423.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012346885_134020294206111297.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012379334_134020288389597469.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012379334_134020292081350481.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012447099_134020288495574059.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012447099_134020292177766781.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012487041_134015159579044619.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012487041_134020283556426593.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012487041_134020286337700533.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012495569_134015161000049047.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012495569_134020286073271576.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012497193_134015161184931012.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012497193_134020285843786424.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012498801_134015160824714799.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012498801_134020285553411541.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012499548_134015160058639601.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012499548_134020285242404722.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012500434_134015160430865670.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012500434_134020285001544517.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012500990_134015160225865314.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012500990_134020284682095105.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012520719_134015159879973629.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012520719_134020283947125102.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012533417_134015159700370749.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012533417_134020283666050330.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012533417_134020286463016361.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012538736_134015159368655899.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012538736_134020283296205244.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012540939_134015159160236187.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012540939_134020283047801857.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012548391_134015158772211359.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012548391_134020282605148170.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012550220_134015158940687558.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012550220_134020282729336124.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012558009_134015158609046276.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012558009_134020282325923624.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012559068_134015158263177398.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012559068_134020281752238767.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012568744_134015157828631604.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012568744_134015195848906487.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012574309_134015156347047005.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012574309_134015157562185460.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012574309_134015194539377201.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012574309_134015195556138263.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012578052_134015157176076970.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012578052_134015195380799997.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012578758_134015156777118524.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012578758_134015195161509285.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012578834_134015156955363005.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012578834_134015195000752103.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012579404_134015156621126811.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012579404_134015194819028092.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012584150_134015156456433042.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012584150_134015157640341374.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012584150_134015194619121324.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012584150_134015195651321226.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012584397_134015156163489198.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012584397_134015194363070216.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012590681_134015155690185694.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012590681_134015193953015599.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012592467_134015155799808403.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012592467_134015194076658501.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012592519_134015155903927777.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012592519_134015194158365417.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012599431_134015154811490356.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012599431_134015193716820220.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012606218_134015155502566840.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012606218_134015193537755633.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012612320_134015155333631368.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012612320_134015193350641166.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012620947_134015155159798796.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012620947_134015193157234287.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012638936_134015154666259997.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012638936_134015192836634962.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012641414_134015154506220942.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012641414_134015192650323374.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012655550_134015154346825494.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012655550_134015192470189887.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012668630_134015154022143857.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012668630_134015192272340116.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012668976_134015154172141461.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012668976_134015192082640983.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012676116_134015153845288577.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012676116_134015191869789004.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012676116_134020295331816226.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012683812_134015153542456107.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012683812_134015191582030959.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012693603_134015152667178045.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012693603_134015191334387149.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012694989_134015153398325917.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012694989_134015191116491203.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012695452_134015153229978922.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012695452_134015190868649274.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012696403_134015153041651095.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012696403_134015190615628843.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012700157_134015152834176675.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012700157_134015190419025826.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012702927_134015152525925010.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012702927_134015190231130178.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012709239_134015152359146247.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012709239_134015189949593761.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012712944_134015151995580898.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012712944_134015189759515665.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012713460_134015152152702808.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012713460_134015189575155024.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012714907_134015151847566796.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012714907_134015189313028619.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012730157_134015151536670134.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012730157_134015189071988224.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012733918_134015151693038592.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012733918_134015188182574186.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012746986_134015151362326561.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012746986_134015187966416886.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012757487_134015151169720071.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012757487_134015187775218649.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012767789_134015150853016437.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012767789_134015187572481048.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012768799_134015151008858783.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012768799_134015187306708132.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012768799_134027170717594004.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012827261_134015146813183463.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012827261_134015147730177294.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012873265_134015146918916490.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012873265_134015147820817808.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012930825_134015141988929553.txt
#    -> Duplicado (omitido):   Informes_en_Texto\criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012930825_134015144114645423.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011959421_134026280230087484.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011959421_134026294648261307.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011959423_134026280359688930.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276011959423_134026294775716300.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276006276591_134026277959149611.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012914087_134026280446140898.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915335_134026282103311319.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915339_134026282001828179.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915345_134026282201027335.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915345_134026282911326687.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915476_134026280936770730.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915476_134026295349354594.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915492_134026281132994520.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012915492_134026295713286753.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012924647_134026316291117036.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012925516_134026316399138770.txt
# --------------------------------------------------
# Archivo Original (copiado): Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012983222_134027210160296390.txt
#    -> Duplicado (omitido):   Informes_en_Texto\no_criticos\C__Users_sebas_AppData_Roaming_Carestream_RIS_11.3.0.25596_risappn_CSHRIS_WS_Reporting_R9276012983222_134027210365780790.txt
# --------------------------------------------------
